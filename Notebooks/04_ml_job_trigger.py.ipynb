# %%
print("=== ML Job Triggered ===")
# Out:
# === ML Job Triggered ===

# %%
# %run "/Workspace/Users/aleenaclarethomas20@gmail.com/03_ml_model_optional.py"
# Out:
# Accuracy: 0.974
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            2       0.97      1.00      0.99       974
#            4       0.00      0.00      0.00        26
#
#     accuracy                           0.97      1000
#    macro avg       0.49      0.50      0.49      1000
# weighted avg       0.95      0.97      0.96      1000
# /databricks/python/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /databricks/python/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print("=== ML Job Finished Successfully ===")
# Out:
# === ML Job Finished Successfully ===
